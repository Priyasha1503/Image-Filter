# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyasha1503/Image-Filter/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
def convert_rgb_to_grey(img_array):
    greyscale=np.dot(img_array[...,:3],[0.2989, 0.5870, 0.1140])
    return greyscale
def convert_rgb_to_negative(img_array):
    #Invert the image
    inverted_img=255-img_array
    plt.imshow(inverted_img)
    plt.title("Inverted(Negative) Image")
    plt.axis('off')
    plt.show()

###IMAGE - ORIGINAL
img=Image.open("Little_krishna.jfif")
img_array=np.array(img)
plt.imshow(img_array)
plt.title("Original picture")
plt.axis('off')
plt.show()
###GREY IMAGE - converting and plotting the image...
grey_image=convert_rgb_to_grey(img_array)
plt.imshow(grey_image,cmap="gray")
plt.title("GREY SCALE IMAGE")
plt.axis('off')
plt.show()
###INVERTED IMAGE OR NEGATIVE IMAGE
convert_rgb_to_negative(img_array)
